# %% [markdown]
# Creating Fake Database from different departments

# %%
import sqlite3
from datetime import datetime, timedelta
import random

# Define sample data for each department
departments = {
    "Finance": [
        ("Financial Report Q1", "This is the content of the Finance Q1 report.", "Executive"),
        ("Investment Analysis", "Detailed investment strategies and outcomes.", "Manager"),
        # Add more as needed
    ],
    "HR": [
        ("Policy Update", "New HR policies on leave and remote work.", "Employee"),
        ("Employee Satisfaction Report", "Analysis of employee satisfaction.", "Manager"),
        # Add more as needed
    ],
    "Technical": [
        ("System Architecture", "Technical specifications for system architecture.", "Engineer"),
        ("Tech Roadmap", "Roadmap for upcoming tech projects and improvements.", "Manager"),
        # Add more as needed
    ]
}

# Function to create and populate each department database
def create_department_db(department, data):
    db_name = f"{department.lower()}_db.sqlite"
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    # Create the documents table with metadata fields
    c.execute('''
        CREATE TABLE IF NOT EXISTS documents (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title TEXT,
            content TEXT,
            access_level TEXT,
            created_date TEXT
        )
    ''')
    
    # Populate the table with sample data
    for title, content, access_level in data:
        created_date = (datetime.now() - timedelta(days=random.randint(0, 365))).strftime("%Y-%m-%d")
        c.execute("INSERT INTO documents (title, content, access_level, created_date) VALUES (?, ?, ?, ?)", 
                  (title, content, access_level, created_date))
    
    conn.commit()
    print(f"Database for {department} created with sample data.")
    conn.close()

# Create each department's database
for department, data in departments.items():
    create_department_db(department, data)
# Out:
# Database for Finance created with sample data.
# Database for HR created with sample data.
# Database for Technical created with sample data.

# %% [markdown]
# Check the random database created

# %%
def check_database(department):
    db_name = f"{department.lower()}_db.sqlite"
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    # Fetch all records from the documents table
    c.execute("SELECT * FROM documents")
    records = c.fetchall()
    
    # Print the results
    print(f"\n--- {department} Database ---")
    for record in records:
        print(record)
    
    conn.close()

# %%
for dept in departments:
    check_database(dept)
# Out:
# --- Finance Database ---
# (1, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2023-12-03')
# (2, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-02-17')
# (3, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-09-05')
# (4, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-06-22')
# (5, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2023-11-28')
# (6, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-07-17')
# (7, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-10-16')
# (8, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-02-09')
# (9, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2023-11-11')
# (10, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-10-13')
# (11, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-02-16')
# (12, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-02-07')
# (13, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-07-11')
# (14, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2023-11-26')
# (15, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2023-12-12')
# (16, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-05-04')
# (17, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-01-17')
# (18, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-09-16')
# (19, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-07-19')
# (20, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2023-11-30')
# (21, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2023-12-03')
# (22, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-01-25')
# (23, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-10-02')
# (24, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-10-20')
# (25, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-04-27')
# (26, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-05-26')
# (27, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-04-30')
# (28, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2023-11-27')
# (29, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-01-21')
# (30, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-06-16')
# (31, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-05-02')
# (32, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-08-24')
# (33, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-09-24')
# (34, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-04-05')
# (35, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2023-11-19')
# (36, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-06-01')
# (37, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-09-24')
# (38, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2024-09-22')
# (39, 'Financial Report Q1', 'This is the content of the Finance Q1 report.', 'Executive', '2024-09-28')
# (40, 'Investment Analysis', 'Detailed investment strategies and outcomes.', 'Manager', '2023-12-26')
#
# --- HR Database ---
# (1, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2023-11-22')
# (2, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-04-10')
# (3, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-07-02')
# (4, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-05-22')
# (5, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2023-12-06')
# (6, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-04-19')
# (7, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-09-06')
# (8, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-09-03')
# (9, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2023-11-16')
# (10, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-03-04')
# (11, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-01-27')
# (12, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-04-01')
# (13, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-05-26')
# (14, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-05-26')
# (15, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-09-07')
# (16, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-09-18')
# (17, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-04-23')
# (18, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-02-29')
# (19, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-03-22')
# (20, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-03-18')
# (21, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-01-06')
# (22, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-08-14')
# (23, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-09-28')
# (24, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-10-04')
# (25, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-05-17')
# (26, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2023-12-28')
# (27, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-09-27')
# (28, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-08-18')
# (29, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-01-14')
# (30, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-09-12')
# (31, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-06-04')
# (32, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-01-29')
# (33, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-07-12')
# (34, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-05-23')
# (35, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-07-24')
# (36, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2023-11-06')
# (37, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-05-18')
# (38, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2024-02-03')
# (39, 'Policy Update', 'New HR policies on leave and remote work.', 'Employee', '2024-08-01')
# (40, 'Employee Satisfaction Report', 'Analysis of employee satisfaction.', 'Manager', '2023-12-12')
#
# --- Technical Database ---
# (1, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-08-29')
# (2, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-09-05')
# (3, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-05-24')
# (4, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-10-19')
# (5, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2023-11-09')
# (6, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-06-16')
# (7, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-01-17')
# (8, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-10-26')
# (9, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-10-22')
# (10, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-08-11')
# (11, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-08-31')
# (12, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-07-13')
# (13, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-03-12')
# (14, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-08-08')
# (15, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-01-10')
# (16, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-08-08')
# (17, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-03-25')
# (18, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-04-30')
# (19, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-08-07')
# (20, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-09-15')
# (21, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-09-29')
# (22, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-01-18')
# (23, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-07-19')
# (24, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-07-23')
# (25, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-07-15')
# (26, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-04-13')
# (27, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-03-22')
# (28, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-07-10')
# (29, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-01-21')
# (30, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-09-18')
# (31, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-03-03')
# (32, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-04-29')
# (33, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-06-15')
# (34, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-01-30')
# (35, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2024-06-04')
# (36, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-07-15')
# (37, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2023-12-18')
# (38, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-03-25')
# (39, 'System Architecture', 'Technical specifications for system architecture.', 'Engineer', '2023-12-22')
# (40, 'Tech Roadmap', 'Roadmap for upcoming tech projects and improvements.', 'Manager', '2024-07-07')

# %%
departments
# Out:
# {'Finance': [('Financial Report Q1',
#    'This is the content of the Finance Q1 report.',
#    'Executive'),
#   ('Investment Analysis',
#    'Detailed investment strategies and outcomes.',
#    'Manager')],
#  'HR': [('Policy Update',
#    'New HR policies on leave and remote work.',
#    'Employee'),
#   ('Employee Satisfaction Report',
#    'Analysis of employee satisfaction.',
#    'Manager')],
#  'Technical': [('System Architecture',
#    'Technical specifications for system architecture.',
#    'Engineer'),
#   ('Tech Roadmap',
#    'Roadmap for upcoming tech projects and improvements.',
#    'Manager')]}

# %%
import sqlite3
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# Initialize the embedding model
model = SentenceTransformer('all-MiniLM-L6-v2')
embedding_dim = model.get_sentence_embedding_dimension()

# Initialize the Faiss index
index = faiss.IndexFlatL2(embedding_dim)

# Dictionary to map document IDs to metadata for retrieval
doc_metadata = {}

# Function to embed and add documents to the Faiss index
def embed_documents_from_db(department):
    db_name = f"{department.lower()}_db.sqlite"
    conn = sqlite3.connect(db_name)
    c = conn.cursor()
    
    # Fetch all documents from the department's database
    c.execute("SELECT id, title, content, access_level FROM documents")
    documents = c.fetchall()
    
    for doc_id, title, content, access_level in documents:
        # Generate an embedding for the content
        embedding = model.encode(content)
        
        # Add embedding to the Faiss index
        index.add(np.array([embedding], dtype=np.float32))
        
        # Store metadata in a dictionary for reference during retrieval
        doc_metadata[len(doc_metadata)] = {
            "doc_id": doc_id,
            "title": title,
            "department": department,
            "access_level": access_level,
            "content": content
        }
    
    conn.close()
    print(f"Documents from {department} embedded and added to Faiss index.")

# List of departments to process
departments = ["Finance", "HR", "Technical"]

# Process each department and embed documents
for dept in departments:
    embed_documents_from_db(dept)

print("All documents embedded and stored in Faiss index.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import sqlite3
# ----> 2 from sentence_transformers import SentenceTransformer
#       3 import faiss
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'sentence_transformers'
